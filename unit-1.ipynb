# %% [markdown]
# # Unit 1 Intro: LunarLander
#
# Use high-level libraries to train an agent for the OpenAI Gym LunarLander environment.

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### Create a virtual display for video rendering

# %%
import os
import time

import gym
import numpy as np

from math import pi

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login
from pyvirtualdisplay import Display
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
display = Display(visible=0, size=(1400, 900))
_ = display.start()

# %% [markdown]
# # Environment demo

# %%
env = gym.make('LunarLander-v2')

print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape:", env.observation_space.shape)
print("Sample observation:", env.observation_space.sample()) # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape:", env.action_space.n)
print("Action Space Sample:", env.action_space.sample()) # Take a random action
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape: (8,)
# Sample observation: [-1.7677496e-01  6.4206737e-01  4.7862220e-01 -1.4629478e-02
#  -1.6274517e+00 -9.5955265e-01  5.3424883e-04  1.6856719e+00]
#
#  _____ACTION SPACE_____
#
# Action Space Shape: 4
# Action Space Sample: 1

# %%
# Reset and get first observation
observation = env.reset()

for _ in range(5):
    # Take a random action
    action = env.action_space.sample()
    print(f'Action taken: {action}')
    
    observation, reward, done, info = env.step(action)
    
    if done:
        print(f'Finished! Resetting environment')
        observation = env.reset()
# Out:
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 1

# %% [markdown]
# # Train an agent

# %%
# max_lr = 0.00055
# def lr(x):
#     if x < 0.02:
#         return 50 * x * max_lr
#     else:
#         return 0.5 * (1 + np.cos(9 * pi * (x - 0.02))) * max_lr * (0.2 + 0.8 * (x < 0.5))
    
    
max_lr = 0.0005
def lr(x):
    if x < 0.05:
        return 50 * x * max_lr
    elif x < 0.333333:
        return max_lr
    else:
        return 0.5 * (1 + np.cos(1.3 * pi * 3 * (x - 0.333333))) * max_lr

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.99,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    learning_rate=lr,
    # learning_rate=lambda x: 0.00033 * (1 - 3.5 * (x - 0.47)**2),
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.03,
    verbose=1)
# Out:
# Using cuda device

# %%
model_name = 'ppo-LunarLander-v2_v3'
model.set_parameters(model_name)

# %%
model_name = 'ppo-LunarLander-v2_tjdebug'
model.learn(total_timesteps=1000000)
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.1     |
# |    ep_rew_mean     | -170     |
# | time/              |          |
# |    fps             | 7368     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.4        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 5265        |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005990468 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -4.2e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 3.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 4767        |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008270159 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00388    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 588         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 4554        |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005754593 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000775   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 425         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 794         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 4414        |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008209404 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 310         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 626         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -99.3       |
# | time/                   |             |
# |    fps                  | 4314        |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009294262 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.018      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 611         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | -71.3      |
# | time/                   |            |
# |    fps                  | 4252       |
# |    iterations           | 7          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00896543 |
# |    clip_fraction        | 0.0701     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.137      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 157        |
# |    n_updates            | 24         |
# |    policy_gradient_loss | -0.00665   |
# |    value_loss           | 500        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -53.1       |
# | time/                   |             |
# |    fps                  | 4207        |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010272205 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 281         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 369         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | -36.4       |
# | time/                   |             |
# |    fps                  | 4135        |
# |    iterations           | 9           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010958938 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 118         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 331         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -17.5       |
# | time/                   |             |
# |    fps                  | 4027        |
# |    iterations           | 10          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006578359 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 379         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -15.1        |
# | time/                   |              |
# |    fps                  | 3822         |
# |    iterations           | 11           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0068867123 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.442        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 299          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 364          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | -21.7        |
# | time/                   |              |
# |    fps                  | 3558         |
# |    iterations           | 12           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0077964775 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 326          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00444     |
# |    value_loss           | 384          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 293         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 13          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.004484047 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 355         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | -14.2        |
# | time/                   |              |
# |    fps                  | 3116         |
# |    iterations           | 14           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0056932895 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 373          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | -4.84       |
# | time/                   |             |
# |    fps                  | 2942        |
# |    iterations           | 15          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.006229188 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 215         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 3.25        |
# | time/                   |             |
# |    fps                  | 2775        |
# |    iterations           | 16          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.004195294 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 174         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 605          |
# |    ep_rew_mean          | 15.7         |
# | time/                   |              |
# |    fps                  | 2652         |
# |    iterations           | 17           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0059452616 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.2         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 194          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 647         |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 2546        |
# |    iterations           | 18          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005097459 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50          |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 723         |
# |    ep_rew_mean          | 32.4        |
# | time/                   |             |
# |    fps                  | 2465        |
# |    iterations           | 19          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.006364489 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 162         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 41.5         |
# | time/                   |              |
# |    fps                  | 2407         |
# |    iterations           | 20           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0042168354 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.574        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.6         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.000868    |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 767          |
# |    ep_rew_mean          | 53.9         |
# | time/                   |              |
# |    fps                  | 2341         |
# |    iterations           | 21           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0058032973 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -7.57e-05    |
# |    value_loss           | 152          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 65.6         |
# | time/                   |              |
# |    fps                  | 2294         |
# |    iterations           | 22           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0032851638 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.7         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000816    |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 848         |
# |    ep_rew_mean          | 76.7        |
# | time/                   |             |
# |    fps                  | 2258        |
# |    iterations           | 23          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.006963241 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.000713   |
# |    value_loss           | 78.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 843         |
# |    ep_rew_mean          | 83.2        |
# | time/                   |             |
# |    fps                  | 2227        |
# |    iterations           | 24          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006071265 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 36.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | 86.5         |
# | time/                   |              |
# |    fps                  | 2190         |
# |    iterations           | 25           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0050358856 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 69.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 863         |
# |    ep_rew_mean          | 88.5        |
# | time/                   |             |
# |    fps                  | 2166        |
# |    iterations           | 26          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.006030602 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.58        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 71.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 96.1        |
# | time/                   |             |
# |    fps                  | 2140        |
# |    iterations           | 27          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.003708622 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.1        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 71.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | 97.8         |
# | time/                   |              |
# |    fps                  | 2115         |
# |    iterations           | 28           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0045971964 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 18           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 873          |
# |    ep_rew_mean          | 99.3         |
# | time/                   |              |
# |    fps                  | 2095         |
# |    iterations           | 29           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0043057846 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 58.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 884          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 2076         |
# |    iterations           | 30           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0039318567 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.48         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.000897    |
# |    value_loss           | 68           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 862         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 2062        |
# |    iterations           | 31          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004305687 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -8.61e-05   |
# |    value_loss           | 74.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 870          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 2043         |
# |    iterations           | 32           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0037960412 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.6         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000276    |
# |    value_loss           | 79           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 832         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 2037        |
# |    iterations           | 33          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.004119819 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.53        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.000248   |
# |    value_loss           | 44.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 2025        |
# |    iterations           | 34          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003043734 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 70.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 836          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 2016         |
# |    iterations           | 35           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0056498954 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000166    |
# |    value_loss           | 41           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 835          |
# |    ep_rew_mean          | 118          |
# | time/                   |              |
# |    fps                  | 2006         |
# |    iterations           | 36           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0043834224 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.3         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 2002         |
# |    iterations           | 37           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0068033827 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86.2         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 49           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 842          |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 1993         |
# |    iterations           | 38           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0041329265 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.6         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 57.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 849          |
# |    ep_rew_mean          | 118          |
# | time/                   |              |
# |    fps                  | 1985         |
# |    iterations           | 39           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0051232525 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.000345     |
# |    value_loss           | 32.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 872         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 1977        |
# |    iterations           | 40          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.005176801 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.08        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000544   |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 902         |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 1969        |
# |    iterations           | 41          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.005061631 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000435   |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 1961        |
# |    iterations           | 42          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004748225 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.000793   |
# |    value_loss           | 4.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 939         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 1958        |
# |    iterations           | 43          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.003910605 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000644   |
# |    value_loss           | 24.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 1955         |
# |    iterations           | 44           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0047158604 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.79         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | 0.000693     |
# |    value_loss           | 25.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 1952         |
# |    iterations           | 45           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0038973133 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.000229     |
# |    value_loss           | 16.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 1951         |
# |    iterations           | 46           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0043125264 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.874        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000671     |
# |    value_loss           | 3.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 1949         |
# |    iterations           | 47           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0033449116 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000282    |
# |    value_loss           | 15.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 1948         |
# |    iterations           | 48           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0038663142 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 25.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 1947         |
# |    iterations           | 49           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0045212656 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | 2.77e-05     |
# |    value_loss           | 15.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 1945         |
# |    iterations           | 50           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0035770491 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.789       |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000246    |
# |    value_loss           | 56.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1945         |
# |    iterations           | 51           |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0041164923 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000136     |
# |    value_loss           | 39.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1943         |
# |    iterations           | 52           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0031886913 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.807       |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000122    |
# |    value_loss           | 57           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 870          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 1942         |
# |    iterations           | 53           |
# |    time_elapsed         | 447          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0026647206 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | 0.000235     |
# |    value_loss           | 50.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 892          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 1938         |
# |    iterations           | 54           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0046205535 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3          |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 7.25e-05     |
# |    value_loss           | 29.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1938         |
# |    iterations           | 55           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0048280796 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | 0.000556     |
# |    value_loss           | 23.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 863          |
# |    ep_rew_mean          | 135          |
# | time/                   |              |
# |    fps                  | 1938         |
# |    iterations           | 56           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0051475484 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000314    |
# |    value_loss           | 57.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 1938         |
# |    iterations           | 57           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0036768126 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.3         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000342    |
# |    value_loss           | 50.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 858        |
# |    ep_rew_mean          | 136        |
# | time/                   |            |
# |    fps                  | 1938       |
# |    iterations           | 58         |
# |    time_elapsed         | 490        |
# |    total_timesteps      | 950272     |
# | train/                  |            |
# |    approx_kl            | 0.00444089 |
# |    clip_fraction        | 0.0593     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.846     |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.49       |
# |    n_updates            | 228        |
# |    policy_gradient_loss | -6.27e-05  |
# |    value_loss           | 3.38       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 869          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 1941         |
# |    iterations           | 59           |
# |    time_elapsed         | 497          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0072260615 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 95.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 857          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 1942         |
# |    iterations           | 60           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0046327272 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.29         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 22.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 847          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 1941         |
# |    iterations           | 61           |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0039462307 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.388        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 9.12e-05     |
# |    value_loss           | 62.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 62          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.003233242 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 244         |
# |    policy_gradient_loss | 0.000299    |
# |    value_loss           | 41.3        |
# -----------------------------------------

# %% [markdown]
# ### Evaluate trained model

# %%
eval_env = gym.make('LunarLander-v2')
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100, deterministic=True)
print(f'Reward = {mean_reward:.2f} +/- {std_reward}')
# Out:
# Reward = 272.11 +/- 33.54414533036526

# %% [markdown]
# ### Upload trained model

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
env_id = 'LunarLander-v2'
model_architecture = 'PPO'
user_name = 'matt-guay'
version = 4
repo_id = f'{user_name}/{model_architecture}-{env_id}-{version}'
commit_message = 'Upload PPO LunarLander-v2 trained agent'

eval_env = DummyVecEnv([lambda: gym.make(env_id)])

package_to_hub(
    model=model,
    model_name=model_name,
    model_architecture=model_architecture,
    env_id=env_id,
    eval_env=eval_env,
    video_length=0,
    repo_id=repo_id,
    commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/matt/venv/hfrl/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Unknown encoder 'libx264'
# ERROR: VideoRecorder encoder failed: None
# ERROR: VideoRecorder encoder exited with status 1
# ffmpeg version b4f2eb3 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.3.0-1ubuntu1~22.04)
#   configuration: --enable-cuda --enable-cuvid --enable-shared --disable-static --disable-doc --extra-cflags=-I/usr/local/cuda/include --extra-ldflags=-L/usr/local/cuda/lib64 --enable-gpl --extra-libs=-lpthread --nvccflags='-gencode arch=compute_86,code=sm_86'
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x56115166b280] Format mov,mp4,m4a,3gp,3g2,mj2 detected only with low score of 1, misdetection possible!
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x56115166b280] moov atom not found
# /tmp/tmpb8qe42b4/-step-0-to-step-0.mp4: Invalid data found when processing input
# Saving video to /tmp/tmpb8qe42b4/-step-0-to-step-0.mp4
# ℹ Pushing repo matt-guay/PPO-LunarLander-v2-4 to the Hugging Face
# Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/matt-guay/PPO-LunarLander-v2-4/tree/main/
# 'https://huggingface.co/matt-guay/PPO-LunarLander-v2-4/tree/main/'
