# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# %cd content/rl-baselines3-zoo/
# Out:
# /media/DataDrive/Dropbox/code/hfrl/content/rl-baselines3-zoo

# %%
# !python train.py --algo dqn --env SpaceInvadersNoFrameskip-v4 -f logs/

# %%
# !python enjoy.py --algo dqn --env SpaceInvadersNoFrameskip-v4 --no-render --n-timesteps 10000 --folder logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 10 frames
# Wrapping the env in a VecTransposeImage.
# Atari Episode Score: 540.00
# Atari Episode Length 2939
# Atari Episode Score: 645.00
# Atari Episode Length 3644
# Atari Episode Score: 645.00
# Atari Episode Length 3644
# Atari Episode Score: 740.00
# Atari Episode Length 3448
# Atari Episode Score: 745.00
# Atari Episode Length 2818
# Atari Episode Score: 740.00
# Atari Episode Length 3448
# Atari Episode Score: 540.00
# Atari Episode Length 3312
# Atari Episode Score: 740.00
# Atari Episode Length 3448
# Atari Episode Score: 1070.00
# Atari Episode Length 6800
# Atari Episode Score: 645.00
# Atari Episode Length 3644
# Atari Episode Score: 745.00
# Atari Episode Length 2986

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

# %%
notebook_login()
# !git config --global credential.helper store

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4_v2 -orga matt-guay -f logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 10 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to matt-guay/dqn-SpaceInvadersNoFrameskip-v4_v2, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Cloning https://huggingface.co/matt-guay/dqn-SpaceInvadersNoFrameskip-v4_v2 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4_v2/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpojlmhn6y/-step-0-to-step-1000.mp4
# ffmpeg version N-109687-gc0cf2c4786 Copyright (c) 2000-2023 the FFmpeg developers
# ...
